# %%
print("Ans1")
print("Flask is a web framework. It provides you with tools, libraries and technologies that allow you to build a web application. This web application can be some web pages, a blog, a wiki or go as big as a web-based calendar application or a commercial website.\n")
print('''Advantage of flask \n
1: Website development
2:Scalable. Size is everything, and Flask's status as a microframework means that we can use it to grow a tech project such as a web app incredibly quickly. ...
3:Flexible. 
4:Lightweight.
''')
# Out:
# Ans1
# Flask is a web framework. It provides you with tools, libraries and technologies that allow you to build a web application. This web application can be some web pages, a blog, a wiki or go as big as a web-based calendar application or a commercial website.
#
# Advantage of flask
#
# 1: Website development
# 2:Scalable. Size is everything, and Flask's status as a microframework means that we can use it to grow a tech project such as a web app incredibly quickly. ...
# 3:Flexible.
# 4:Lightweight.

# %% [markdown]
# ![Picture1.png](attachment:03444404-a522-4889-acc9-4289740b8dcd.png)

# %%
print("Ans3")
print("App Routing means mapping the URLs to a specific function that will handle the logic for that URL\n")
print("App routing is used to map the specific URL with the associated function that is intended to perform some task. It is used to access some particular page in web application")
# Out:
# Ans3
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL
#
# App routing is used to map the specific URL with the associated function that is intended to perform some task. It is used to access some particular page in web application

# %%
print("Ans4")
# Out:
# Ans4

# %% [markdown]
# ![Picture2.png](attachment:5636217a-4587-49f0-839a-529cf4c8ce35.png)

# %% [markdown]
# Ans4
#
# ![Picture3.png](attachment:abb48feb-2923-4f61-87a2-3edfeb498481.png)

# %% [markdown]
# print("Ans5")
#
# print('''
# "url_for() function" is used in Flask for URL Building
# ''')
#
# print("python code link is there in github repository")
# https://github.com/aruneshraj1995/url_for-

# %% [markdown]
# ![Picture4.png](attachment:e6ae3d62-fbdc-4d6c-964f-966214bbe032.png)
